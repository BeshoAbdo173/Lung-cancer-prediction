# %%
# !pip install librosa
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.4.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.7.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.56.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.21.6)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.39.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (4.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.43.0->librosa) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.43.0->librosa) (3.8.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.47.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)

# %%
# !pip install preprocess
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting preprocess
#   Downloading preprocess-2.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from preprocess) (0.16.0)
# Installing collected packages: preprocess
# Successfully installed preprocess-2.0.0

# %%
import librosa
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
from tqdm import tqdm
import librosa.display

# %%
from preprocess import *
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LSTM
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
filepath = "/content/drive/MyDrive/NLP-ASR-MODEL/Old & New data/audio/Straight Mayo Scissor/StMySc_057.wav"
ipd.Audio(filepath)
data, sample_rate = librosa.load(filepath)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(data, sr=sample_rate)
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filepath)
print(wave_sample_rate)
print(wave_audio)
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
plt.plot(wave_audio)
# Out:
# 48000
# [      0       0       0 ... 1394732 2390464 3198247]

# %%
filepath = "/content/drive/MyDrive/NLP-ASR-MODEL/Old & New data/audio/Straight Mayo Scissor/StMySc_040.wav"
ipd.Audio(filepath)
data, sample_rate = librosa.load(filepath)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(data, sr=sample_rate)
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filepath)
print(wave_sample_rate)
print(wave_audio)
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
plt.plot(wave_audio)
# Out:
# 48000
# [[ 0.0000000e+00  0.0000000e+00]
#  [ 0.0000000e+00  0.0000000e+00]
#  [ 0.0000000e+00  0.0000000e+00]
#  ...
#  [-5.5893917e-08 -5.5893917e-08]
#  [-2.4920292e-08 -2.4920292e-08]
#  [-6.2841887e-09 -6.2841887e-09]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   import sys
# [<matplotlib.lines.Line2D at 0x7fc8079a6e90>,
#  <matplotlib.lines.Line2D at 0x7fc807931110>]

# %%
filepath = "/content/drive/MyDrive/NLP-ASR-MODEL/Old & New data/audio/Scalpel/scalp_005.wav"
ipd.Audio(filepath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data, sample_rate = librosa.load(filepath)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(data, sr=sample_rate)

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filepath)
print(wave_sample_rate)
print(wave_audio)
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4) )
plt.plot(wave_audio)
# Out:
# 48000
# [[ 2.4498996e-09  2.4498996e-09]
#  [ 8.6391427e-09  8.6391427e-09]
#  [ 1.6933564e-08  1.6933564e-08]
#  ...
#  [-5.0924770e-03 -5.0924770e-03]
#  [-1.0197026e-02 -1.0197026e-02]
#  [-1.4922608e-02 -1.4922608e-02]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
# [<matplotlib.lines.Line2D at 0x7f42294820d0>,
#  <matplotlib.lines.Line2D at 0x7f4229482310>]

# %%
import pandas as pd
metadata = pd.read_csv('/content/drive/MyDrive/NLP-ASR-MODEL/metadata/Instruments.csv')
metadata.head(400)
# Out:
#     slice_file_name  fold  classID                class
# 0          16_2.wav     1        0              scalpel
# 1          17_2.wav     1        0              scalpel
# 2          18_2.wav     1        0              scalpel
# 3          19_2.wav     1        0              scalpel
# 4          20_2.wav     1        0              scalpel
# ..              ...   ...      ...                  ...
# 395         421.wav     4        3  curved_mayo_sicssor
# 396         422.wav     4        3  curved_mayo_sicssor
# 397         423.wav     4        3  curved_mayo_sicssor
# 398         424.wav     4        3  curved_mayo_sicssor
# 399         425.wav     4        3  curved_mayo_sicssor
#
# [400 rows x 4 columns]

# %%
metadata['class'].value_counts()
# Out:
# scalpel                      105
# straight_dissection_clamp    100
# curved_mayo_sicssor          100
# straight_mayo_sicssor         95
# Name: class, dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.countplot(metadata['class'])
plt.title("Count of records in each class")
plt.xticks(rotation="vertical")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
mfccs = librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=40)
print(mfccs.shape)
print(mfccs)
# Out:
# (40, 34)
# [[-4.70018524e+02 -3.71013367e+02 -3.28188904e+02 ... -4.37156403e+02
#   -4.65598480e+02 -4.98810822e+02]
#  [ 5.28076706e+01  4.55671997e+01  4.51126518e+01 ...  1.20677414e+02
#    1.05956390e+02  8.62005386e+01]
#  [ 1.70801926e+01 -9.89803600e+00 -2.21241035e+01 ...  4.28918686e+01
#    5.09903946e+01  5.15907288e+01]
#  ...
#  [ 5.71242869e-01  1.35220230e+00  1.22018754e+00 ... -6.06598496e-01
#    2.21202016e+00 -4.05597359e-01]
#  [ 4.35419619e-01 -3.25689650e+00 -5.54294348e+00 ...  4.12426090e+00
#    5.85067081e+00  3.05224276e+00]
#  [-5.23859692e+00  6.24134421e-01  3.19210005e+00 ...  1.23080072e+01
#    1.25821657e+01  8.13436031e+00]]

# %%
def features_extractor(file):
    #load the file (audio)
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    #we extract mfcc
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    #in order to find out scaled feature we do mean of transpose of value
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
#Now we ned to extract the featured from all the audio files so we use tqdm
import numpy as np
from tqdm import tqdm
### Now we iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath('/content/drive/MyDrive/NLP-ASR-MODEL/Data/'),str(row["slice_file_name"]))
    final_class_labels=row["class"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 400it [03:15,  2.04it/s]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature    class
# 0  [-377.4645, 61.72468, -27.067968, 30.731216, -...  scalpel
# 1  [-385.23694, 71.85136, -16.470957, 36.42555, -...  scalpel
# 2  [-382.9297, 73.41553, -27.842405, 35.637627, -...  scalpel
# 3  [-400.645, 69.08369, -18.337183, 35.613712, -9...  scalpel
# 4  [-395.57275, 66.22247, -33.789635, 33.84744, -...  scalpel

# %%
### Split the dataset into independent and dependent dataset
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())
### Label Encoding -> Label Encoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import LSTM
from sklearn import metrics
### No of classes
num_labels=y.shape[1]

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.2))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.2))

###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam' )
###, loss='mse'

# %%
## Trianing my model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 
num_epochs = 200
num_batch_size =10
checkpointer = ModelCheckpoint(filepath='/content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()
history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)
duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/200
# 21/32 [==================>...........] - ETA: 0s - loss: 10.3684 - accuracy: 0.3143
# Epoch 1: val_loss improved from inf to 3.52920, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 1s 23ms/step - loss: 9.7856 - accuracy: 0.2781 - val_loss: 3.5292 - val_accuracy: 0.2625
# Epoch 2/200
# 15/32 [=============>................] - ETA: 0s - loss: 5.4434 - accuracy: 0.3133
# Epoch 2: val_loss improved from 3.52920 to 1.51261, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 4.5419 - accuracy: 0.2781 - val_loss: 1.5126 - val_accuracy: 0.2875
# Epoch 3/200
# 22/32 [===================>..........] - ETA: 0s - loss: 2.8057 - accuracy: 0.2955
# Epoch 3: val_loss improved from 1.51261 to 1.37274, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 2.8032 - accuracy: 0.2719 - val_loss: 1.3727 - val_accuracy: 0.3500
# Epoch 4/200
# 20/32 [=================>............] - ETA: 0s - loss: 2.0860 - accuracy: 0.2800
# Epoch 4: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 2.0424 - accuracy: 0.2812 - val_loss: 1.3741 - val_accuracy: 0.3125
# Epoch 5/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.6293 - accuracy: 0.2958
# Epoch 5: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6949 - accuracy: 0.2781 - val_loss: 1.3808 - val_accuracy: 0.2625
# Epoch 6/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.4875 - accuracy: 0.3167
# Epoch 6: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.5321 - accuracy: 0.2750 - val_loss: 1.3861 - val_accuracy: 0.2500
# Epoch 7/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.4877 - accuracy: 0.2913
# Epoch 7: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4958 - accuracy: 0.2688 - val_loss: 1.3891 - val_accuracy: 0.2375
# Epoch 8/200
# 22/32 [===================>..........] - ETA: 0s - loss: 1.4685 - accuracy: 0.2455
# Epoch 8: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4684 - accuracy: 0.2313 - val_loss: 1.3897 - val_accuracy: 0.2375
# Epoch 9/200
# 20/32 [=================>............] - ETA: 0s - loss: 1.4433 - accuracy: 0.2800
# Epoch 9: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4272 - accuracy: 0.2781 - val_loss: 1.3890 - val_accuracy: 0.2500
# Epoch 10/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.4355 - accuracy: 0.2565
# Epoch 10: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4547 - accuracy: 0.2531 - val_loss: 1.3866 - val_accuracy: 0.1875
# Epoch 11/200
# 18/32 [===============>..............] - ETA: 0s - loss: 1.4031 - accuracy: 0.3056
# Epoch 11: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3955 - accuracy: 0.3063 - val_loss: 1.3909 - val_accuracy: 0.1750
# Epoch 12/200
# 22/32 [===================>..........] - ETA: 0s - loss: 1.4508 - accuracy: 0.3045
# Epoch 12: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4220 - accuracy: 0.3031 - val_loss: 1.3866 - val_accuracy: 0.2625
# Epoch 13/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.3703 - accuracy: 0.3333
# Epoch 13: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3770 - accuracy: 0.3313 - val_loss: 1.3828 - val_accuracy: 0.1750
# Epoch 14/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.3853 - accuracy: 0.3130
# Epoch 14: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3840 - accuracy: 0.2906 - val_loss: 1.3842 - val_accuracy: 0.1750
# Epoch 15/200
# 21/32 [==================>...........] - ETA: 0s - loss: 1.3603 - accuracy: 0.2905
# Epoch 15: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3711 - accuracy: 0.2937 - val_loss: 1.3834 - val_accuracy: 0.2500
# Epoch 16/200
# 22/32 [===================>..........] - ETA: 0s - loss: 1.4797 - accuracy: 0.2909
# Epoch 16: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4505 - accuracy: 0.3094 - val_loss: 1.3865 - val_accuracy: 0.2625
# Epoch 17/200
# 20/32 [=================>............] - ETA: 0s - loss: 1.3898 - accuracy: 0.2700
# Epoch 17: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4012 - accuracy: 0.2937 - val_loss: 1.3865 - val_accuracy: 0.2625
# Epoch 18/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.3649 - accuracy: 0.3125
# Epoch 18: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3820 - accuracy: 0.3000 - val_loss: 1.3809 - val_accuracy: 0.2500
# Epoch 19/200
# 17/32 [==============>...............] - ETA: 0s - loss: 1.3608 - accuracy: 0.3000
# Epoch 19: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4078 - accuracy: 0.2937 - val_loss: 1.3833 - val_accuracy: 0.2625
# Epoch 20/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.4044 - accuracy: 0.3042
# Epoch 20: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3966 - accuracy: 0.2844 - val_loss: 1.3861 - val_accuracy: 0.2625
# Epoch 21/200
# 25/32 [======================>.......] - ETA: 0s - loss: 1.4054 - accuracy: 0.3240
# Epoch 21: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4040 - accuracy: 0.3281 - val_loss: 1.3736 - val_accuracy: 0.2500
# Epoch 22/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.3324 - accuracy: 0.3913
# Epoch 22: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3468 - accuracy: 0.3594 - val_loss: 1.3802 - val_accuracy: 0.2750
# Epoch 23/200
# 25/32 [======================>.......] - ETA: 0s - loss: 1.3441 - accuracy: 0.2880
# Epoch 23: val_loss did not improve from 1.37274
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3549 - accuracy: 0.3031 - val_loss: 1.3839 - val_accuracy: 0.2625
# Epoch 24/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.3468 - accuracy: 0.3913
# Epoch 24: val_loss improved from 1.37274 to 1.36240, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3469 - accuracy: 0.3844 - val_loss: 1.3624 - val_accuracy: 0.3250
# Epoch 25/200
# 18/32 [===============>..............] - ETA: 0s - loss: 1.3410 - accuracy: 0.3500
# Epoch 25: val_loss did not improve from 1.36240
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3454 - accuracy: 0.3375 - val_loss: 1.3630 - val_accuracy: 0.2875
# Epoch 26/200
# 21/32 [==================>...........] - ETA: 0s - loss: 1.3875 - accuracy: 0.2762
# Epoch 26: val_loss did not improve from 1.36240
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3714 - accuracy: 0.2812 - val_loss: 1.3743 - val_accuracy: 0.2875
# Epoch 27/200
# 21/32 [==================>...........] - ETA: 0s - loss: 1.3300 - accuracy: 0.3333
# Epoch 27: val_loss improved from 1.36240 to 1.35513, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3351 - accuracy: 0.3281 - val_loss: 1.3551 - val_accuracy: 0.3125
# Epoch 28/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.3433 - accuracy: 0.3542
# Epoch 28: val_loss improved from 1.35513 to 1.35080, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3383 - accuracy: 0.3469 - val_loss: 1.3508 - val_accuracy: 0.3000
# Epoch 29/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.3075 - accuracy: 0.3652
# Epoch 29: val_loss improved from 1.35080 to 1.33637, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 1.3192 - accuracy: 0.3781 - val_loss: 1.3364 - val_accuracy: 0.3000
# Epoch 30/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.3011 - accuracy: 0.3696
# Epoch 30: val_loss improved from 1.33637 to 1.32987, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3075 - accuracy: 0.3719 - val_loss: 1.3299 - val_accuracy: 0.3125
# Epoch 31/200
# 25/32 [======================>.......] - ETA: 0s - loss: 1.2825 - accuracy: 0.3480
# Epoch 31: val_loss improved from 1.32987 to 1.32093, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3015 - accuracy: 0.3375 - val_loss: 1.3209 - val_accuracy: 0.3000
# Epoch 32/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.3129 - accuracy: 0.3708
# Epoch 32: val_loss improved from 1.32093 to 1.31314, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 1.3146 - accuracy: 0.3531 - val_loss: 1.3131 - val_accuracy: 0.2500
# Epoch 33/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.2549 - accuracy: 0.4130
# Epoch 33: val_loss improved from 1.31314 to 1.28226, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.2795 - accuracy: 0.4094 - val_loss: 1.2823 - val_accuracy: 0.3375
# Epoch 34/200
# 21/32 [==================>...........] - ETA: 0s - loss: 1.1870 - accuracy: 0.4810
# Epoch 34: val_loss improved from 1.28226 to 1.27665, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.2409 - accuracy: 0.4500 - val_loss: 1.2766 - val_accuracy: 0.4625
# Epoch 35/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.2818 - accuracy: 0.4208
# Epoch 35: val_loss did not improve from 1.27665
# 32/32 [==============================] - 0s 4ms/step - loss: 1.2713 - accuracy: 0.4187 - val_loss: 1.2925 - val_accuracy: 0.4375
# Epoch 36/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.2567 - accuracy: 0.4042
# Epoch 36: val_loss did not improve from 1.27665
# 32/32 [==============================] - 0s 4ms/step - loss: 1.2473 - accuracy: 0.4125 - val_loss: 1.2922 - val_accuracy: 0.4250
# Epoch 37/200
# 16/32 [==============>...............] - ETA: 0s - loss: 1.2610 - accuracy: 0.4062
# Epoch 37: val_loss improved from 1.27665 to 1.25496, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 1.2903 - accuracy: 0.4187 - val_loss: 1.2550 - val_accuracy: 0.4500
# Epoch 38/200
# 22/32 [===================>..........] - ETA: 0s - loss: 1.2089 - accuracy: 0.4955
# Epoch 38: val_loss improved from 1.25496 to 1.24756, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.2137 - accuracy: 0.4812 - val_loss: 1.2476 - val_accuracy: 0.5000
# Epoch 39/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.2159 - accuracy: 0.4125
# Epoch 39: val_loss did not improve from 1.24756
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1957 - accuracy: 0.4406 - val_loss: 1.2673 - val_accuracy: 0.4125
# Epoch 40/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.2218 - accuracy: 0.4696
# Epoch 40: val_loss improved from 1.24756 to 1.16937, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.1875 - accuracy: 0.4844 - val_loss: 1.1694 - val_accuracy: 0.4750
# Epoch 41/200
# 18/32 [===============>..............] - ETA: 0s - loss: 1.1489 - accuracy: 0.4889
# Epoch 41: val_loss did not improve from 1.16937
# 32/32 [==============================] - 0s 4ms/step - loss: 1.1318 - accuracy: 0.4938 - val_loss: 1.1847 - val_accuracy: 0.4875
# Epoch 42/200
# 23/32 [====================>.........] - ETA: 0s - loss: 1.1302 - accuracy: 0.4957
# Epoch 42: val_loss improved from 1.16937 to 1.15730, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.1525 - accuracy: 0.4875 - val_loss: 1.1573 - val_accuracy: 0.5125
# Epoch 43/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.1297 - accuracy: 0.4833
# Epoch 43: val_loss improved from 1.15730 to 1.14588, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.1181 - accuracy: 0.4969 - val_loss: 1.1459 - val_accuracy: 0.5250
# Epoch 44/200
# 18/32 [===============>..............] - ETA: 0s - loss: 1.0507 - accuracy: 0.5444
# Epoch 44: val_loss improved from 1.14588 to 1.07686, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0917 - accuracy: 0.5188 - val_loss: 1.0769 - val_accuracy: 0.6000
# Epoch 45/200
# 22/32 [===================>..........] - ETA: 0s - loss: 1.0873 - accuracy: 0.5136
# Epoch 45: val_loss improved from 1.07686 to 1.07126, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0938 - accuracy: 0.5094 - val_loss: 1.0713 - val_accuracy: 0.5500
# Epoch 46/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.9547 - accuracy: 0.5900
# Epoch 46: val_loss improved from 1.07126 to 1.01506, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0093 - accuracy: 0.5469 - val_loss: 1.0151 - val_accuracy: 0.5625
# Epoch 47/200
# 24/32 [=====================>........] - ETA: 0s - loss: 1.0418 - accuracy: 0.5750
# Epoch 47: val_loss did not improve from 1.01506
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0285 - accuracy: 0.5781 - val_loss: 1.0721 - val_accuracy: 0.5000
# Epoch 48/200
# 22/32 [===================>..........] - ETA: 0s - loss: 1.0404 - accuracy: 0.5500
# Epoch 48: val_loss did not improve from 1.01506
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0043 - accuracy: 0.5531 - val_loss: 1.0198 - val_accuracy: 0.5125
# Epoch 49/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.9019 - accuracy: 0.5870
# Epoch 49: val_loss improved from 1.01506 to 0.95690, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9490 - accuracy: 0.5656 - val_loss: 0.9569 - val_accuracy: 0.6000
# Epoch 50/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.9759 - accuracy: 0.6045
# Epoch 50: val_loss improved from 0.95690 to 0.91746, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9697 - accuracy: 0.6156 - val_loss: 0.9175 - val_accuracy: 0.6250
# Epoch 51/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.8774 - accuracy: 0.6391
# Epoch 51: val_loss did not improve from 0.91746
# 32/32 [==============================] - 0s 3ms/step - loss: 0.9253 - accuracy: 0.6125 - val_loss: 0.9251 - val_accuracy: 0.5875
# Epoch 52/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.8562 - accuracy: 0.6292
# Epoch 52: val_loss did not improve from 0.91746
# 32/32 [==============================] - 0s 3ms/step - loss: 0.8875 - accuracy: 0.6219 - val_loss: 0.9180 - val_accuracy: 0.5625
# Epoch 53/200
# 16/32 [==============>...............] - ETA: 0s - loss: 0.8626 - accuracy: 0.6125
# Epoch 53: val_loss did not improve from 0.91746
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9163 - accuracy: 0.6250 - val_loss: 0.9662 - val_accuracy: 0.5750
# Epoch 54/200
# 25/32 [======================>.......] - ETA: 0s - loss: 0.8697 - accuracy: 0.6320
# Epoch 54: val_loss did not improve from 0.91746
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8829 - accuracy: 0.6313 - val_loss: 0.9357 - val_accuracy: 0.5875
# Epoch 55/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.8164 - accuracy: 0.6435
# Epoch 55: val_loss improved from 0.91746 to 0.87083, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.8689 - accuracy: 0.6469 - val_loss: 0.8708 - val_accuracy: 0.6000
# Epoch 56/200
# 25/32 [======================>.......] - ETA: 0s - loss: 0.7806 - accuracy: 0.6440
# Epoch 56: val_loss improved from 0.87083 to 0.78137, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.7753 - accuracy: 0.6562 - val_loss: 0.7814 - val_accuracy: 0.7000
# Epoch 57/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.7642 - accuracy: 0.6875
# Epoch 57: val_loss did not improve from 0.78137
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7490 - accuracy: 0.6719 - val_loss: 0.8207 - val_accuracy: 0.6750
# Epoch 58/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.7595 - accuracy: 0.6800
# Epoch 58: val_loss did not improve from 0.78137
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7610 - accuracy: 0.6750 - val_loss: 0.8223 - val_accuracy: 0.6250
# Epoch 59/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.7482 - accuracy: 0.7000
# Epoch 59: val_loss did not improve from 0.78137
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7809 - accuracy: 0.6906 - val_loss: 0.8331 - val_accuracy: 0.6625
# Epoch 60/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.7193 - accuracy: 0.6833
# Epoch 60: val_loss did not improve from 0.78137
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7431 - accuracy: 0.6719 - val_loss: 0.7833 - val_accuracy: 0.6500
# Epoch 61/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.6938 - accuracy: 0.6762
# Epoch 61: val_loss improved from 0.78137 to 0.74817, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6967 - accuracy: 0.6906 - val_loss: 0.7482 - val_accuracy: 0.7125
# Epoch 62/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.6679 - accuracy: 0.7261
# Epoch 62: val_loss improved from 0.74817 to 0.72091, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6387 - accuracy: 0.7531 - val_loss: 0.7209 - val_accuracy: 0.7375
# Epoch 63/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.7013 - accuracy: 0.7364
# Epoch 63: val_loss improved from 0.72091 to 0.67801, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6559 - accuracy: 0.7594 - val_loss: 0.6780 - val_accuracy: 0.7250
# Epoch 64/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.6967 - accuracy: 0.7053
# Epoch 64: val_loss did not improve from 0.67801
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6447 - accuracy: 0.7406 - val_loss: 0.6838 - val_accuracy: 0.7750
# Epoch 65/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.7132 - accuracy: 0.7042
# Epoch 65: val_loss did not improve from 0.67801
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6918 - accuracy: 0.7250 - val_loss: 0.8060 - val_accuracy: 0.6625
# Epoch 66/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.6910 - accuracy: 0.6952
# Epoch 66: val_loss improved from 0.67801 to 0.67419, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.7129 - accuracy: 0.6938 - val_loss: 0.6742 - val_accuracy: 0.7375
# Epoch 67/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.5955 - accuracy: 0.7435
# Epoch 67: val_loss did not improve from 0.67419
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5991 - accuracy: 0.7437 - val_loss: 0.6935 - val_accuracy: 0.7500
# Epoch 68/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.6421 - accuracy: 0.7565
# Epoch 68: val_loss did not improve from 0.67419
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6427 - accuracy: 0.7375 - val_loss: 0.6930 - val_accuracy: 0.6750
# Epoch 69/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.5438 - accuracy: 0.7750
# Epoch 69: val_loss did not improve from 0.67419
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5447 - accuracy: 0.7812 - val_loss: 0.8006 - val_accuracy: 0.6500
# Epoch 70/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.5295 - accuracy: 0.7636
# Epoch 70: val_loss improved from 0.67419 to 0.61067, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 0.5197 - accuracy: 0.7688 - val_loss: 0.6107 - val_accuracy: 0.7500
# Epoch 71/200
# 25/32 [======================>.......] - ETA: 0s - loss: 0.5164 - accuracy: 0.8120
# Epoch 71: val_loss did not improve from 0.61067
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5369 - accuracy: 0.7844 - val_loss: 0.6702 - val_accuracy: 0.7375
# Epoch 72/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.5871 - accuracy: 0.7458
# Epoch 72: val_loss did not improve from 0.61067
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6012 - accuracy: 0.7469 - val_loss: 0.6392 - val_accuracy: 0.7375
# Epoch 73/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.5606 - accuracy: 0.7571
# Epoch 73: val_loss did not improve from 0.61067
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5398 - accuracy: 0.7719 - val_loss: 0.6886 - val_accuracy: 0.7375
# Epoch 74/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.5085 - accuracy: 0.7682
# Epoch 74: val_loss improved from 0.61067 to 0.56208, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4881 - accuracy: 0.7875 - val_loss: 0.5621 - val_accuracy: 0.7875
# Epoch 75/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.5310 - accuracy: 0.7917
# Epoch 75: val_loss did not improve from 0.56208
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5451 - accuracy: 0.7906 - val_loss: 0.5872 - val_accuracy: 0.7375
# Epoch 76/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.5417 - accuracy: 0.8045
# Epoch 76: val_loss did not improve from 0.56208
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5597 - accuracy: 0.7750 - val_loss: 0.5818 - val_accuracy: 0.7625
# Epoch 77/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.3985 - accuracy: 0.8636
# Epoch 77: val_loss improved from 0.56208 to 0.55007, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4089 - accuracy: 0.8531 - val_loss: 0.5501 - val_accuracy: 0.7875
# Epoch 78/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.4272 - accuracy: 0.8174
# Epoch 78: val_loss did not improve from 0.55007
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4031 - accuracy: 0.8313 - val_loss: 0.5934 - val_accuracy: 0.7500
# Epoch 79/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.4544 - accuracy: 0.8333
# Epoch 79: val_loss improved from 0.55007 to 0.50898, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4693 - accuracy: 0.8188 - val_loss: 0.5090 - val_accuracy: 0.7625
# Epoch 80/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.4154 - accuracy: 0.8174
# Epoch 80: val_loss did not improve from 0.50898
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8281 - val_loss: 0.5987 - val_accuracy: 0.7625
# Epoch 81/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.4370 - accuracy: 0.8182
# Epoch 81: val_loss did not improve from 0.50898
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4393 - accuracy: 0.8313 - val_loss: 0.5800 - val_accuracy: 0.7625
# Epoch 82/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.6355 - accuracy: 0.8167
# Epoch 82: val_loss did not improve from 0.50898
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6193 - accuracy: 0.8188 - val_loss: 0.5483 - val_accuracy: 0.7875
# Epoch 83/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.4647 - accuracy: 0.8000
# Epoch 83: val_loss improved from 0.50898 to 0.49800, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4395 - accuracy: 0.8156 - val_loss: 0.4980 - val_accuracy: 0.8125
# Epoch 84/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.3652 - accuracy: 0.8583
# Epoch 84: val_loss did not improve from 0.49800
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4312 - accuracy: 0.8313 - val_loss: 0.5550 - val_accuracy: 0.7500
# Epoch 85/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.4345 - accuracy: 0.8125
# Epoch 85: val_loss did not improve from 0.49800
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4525 - accuracy: 0.8031 - val_loss: 0.5142 - val_accuracy: 0.7500
# Epoch 86/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.3520 - accuracy: 0.8818
# Epoch 86: val_loss did not improve from 0.49800
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3932 - accuracy: 0.8500 - val_loss: 0.5106 - val_accuracy: 0.7500
# Epoch 87/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.3825 - accuracy: 0.8522
# Epoch 87: val_loss did not improve from 0.49800
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3770 - accuracy: 0.8531 - val_loss: 0.5499 - val_accuracy: 0.7625
# Epoch 88/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.3464 - accuracy: 0.8636
# Epoch 88: val_loss did not improve from 0.49800
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3443 - accuracy: 0.8625 - val_loss: 0.5560 - val_accuracy: 0.8000
# Epoch 89/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.4632 - accuracy: 0.8083
# Epoch 89: val_loss did not improve from 0.49800
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4721 - accuracy: 0.8062 - val_loss: 0.5881 - val_accuracy: 0.7375
# Epoch 90/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.4142 - accuracy: 0.8174
# Epoch 90: val_loss did not improve from 0.49800
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4311 - accuracy: 0.8125 - val_loss: 0.5918 - val_accuracy: 0.7625
# Epoch 91/200
# 18/32 [===============>..............] - ETA: 0s - loss: 0.4127 - accuracy: 0.8333
# Epoch 91: val_loss improved from 0.49800 to 0.49785, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4406 - accuracy: 0.8094 - val_loss: 0.4979 - val_accuracy: 0.7875
# Epoch 92/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.3961 - accuracy: 0.8478
# Epoch 92: val_loss improved from 0.49785 to 0.49387, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3826 - accuracy: 0.8562 - val_loss: 0.4939 - val_accuracy: 0.8000
# Epoch 93/200
# 30/32 [===========================>..] - ETA: 0s - loss: 0.3318 - accuracy: 0.8600
# Epoch 93: val_loss improved from 0.49387 to 0.42158, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3402 - accuracy: 0.8594 - val_loss: 0.4216 - val_accuracy: 0.8500
# Epoch 94/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.3262 - accuracy: 0.8450
# Epoch 94: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3364 - accuracy: 0.8500 - val_loss: 0.5620 - val_accuracy: 0.7625
# Epoch 95/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.3858 - accuracy: 0.8773
# Epoch 95: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4368 - accuracy: 0.8594 - val_loss: 0.5007 - val_accuracy: 0.8250
# Epoch 96/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.4232 - accuracy: 0.8143
# Epoch 96: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3885 - accuracy: 0.8531 - val_loss: 0.5139 - val_accuracy: 0.7750
# Epoch 97/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.3480 - accuracy: 0.8522
# Epoch 97: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3444 - accuracy: 0.8500 - val_loss: 0.4367 - val_accuracy: 0.8125
# Epoch 98/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.3425 - accuracy: 0.8636
# Epoch 98: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3479 - accuracy: 0.8656 - val_loss: 0.4509 - val_accuracy: 0.8250
# Epoch 99/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.3655 - accuracy: 0.8350
# Epoch 99: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3160 - accuracy: 0.8625 - val_loss: 0.4614 - val_accuracy: 0.8125
# Epoch 100/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.2538 - accuracy: 0.8913
# Epoch 100: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2500 - accuracy: 0.8906 - val_loss: 0.4964 - val_accuracy: 0.8250
# Epoch 101/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.4696 - accuracy: 0.8500
# Epoch 101: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4283 - accuracy: 0.8562 - val_loss: 0.5040 - val_accuracy: 0.8000
# Epoch 102/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.3124 - accuracy: 0.8652
# Epoch 102: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3108 - accuracy: 0.8531 - val_loss: 0.4562 - val_accuracy: 0.8125
# Epoch 103/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.3154 - accuracy: 0.8727
# Epoch 103: val_loss did not improve from 0.42158
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3456 - accuracy: 0.8656 - val_loss: 0.4353 - val_accuracy: 0.8250
# Epoch 104/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.3694 - accuracy: 0.8609
# Epoch 104: val_loss improved from 0.42158 to 0.41716, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.8438 - val_loss: 0.4172 - val_accuracy: 0.8000
# Epoch 105/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2805 - accuracy: 0.8857
# Epoch 105: val_loss did not improve from 0.41716
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3233 - accuracy: 0.8687 - val_loss: 0.5493 - val_accuracy: 0.8000
# Epoch 106/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.3235 - accuracy: 0.9000
# Epoch 106: val_loss did not improve from 0.41716
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3809 - accuracy: 0.8562 - val_loss: 0.5904 - val_accuracy: 0.7750
# Epoch 107/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.3352 - accuracy: 0.8579
# Epoch 107: val_loss did not improve from 0.41716
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3038 - accuracy: 0.8719 - val_loss: 0.4700 - val_accuracy: 0.8000
# Epoch 108/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.3722 - accuracy: 0.8211
# Epoch 108: val_loss did not improve from 0.41716
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3281 - accuracy: 0.8594 - val_loss: 0.4576 - val_accuracy: 0.8125
# Epoch 109/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.2666 - accuracy: 0.9050
# Epoch 109: val_loss did not improve from 0.41716
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3017 - accuracy: 0.8781 - val_loss: 0.4724 - val_accuracy: 0.8000
# Epoch 110/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.3252 - accuracy: 0.8429
# Epoch 110: val_loss improved from 0.41716 to 0.41518, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2993 - accuracy: 0.8594 - val_loss: 0.4152 - val_accuracy: 0.8375
# Epoch 111/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2956 - accuracy: 0.8952
# Epoch 111: val_loss did not improve from 0.41518
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2822 - accuracy: 0.8938 - val_loss: 0.4397 - val_accuracy: 0.8000
# Epoch 112/200
# 25/32 [======================>.......] - ETA: 0s - loss: 0.2423 - accuracy: 0.9120
# Epoch 112: val_loss improved from 0.41518 to 0.40645, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2250 - accuracy: 0.9156 - val_loss: 0.4064 - val_accuracy: 0.8250
# Epoch 113/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.2413 - accuracy: 0.9333
# Epoch 113: val_loss did not improve from 0.40645
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2438 - accuracy: 0.9219 - val_loss: 0.4552 - val_accuracy: 0.8250
# Epoch 114/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.2610 - accuracy: 0.9105
# Epoch 114: val_loss did not improve from 0.40645
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.9125 - val_loss: 0.4234 - val_accuracy: 0.8250
# Epoch 115/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2909 - accuracy: 0.9238
# Epoch 115: val_loss did not improve from 0.40645
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2622 - accuracy: 0.9156 - val_loss: 0.4215 - val_accuracy: 0.8375
# Epoch 116/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.2660 - accuracy: 0.9042
# Epoch 116: val_loss did not improve from 0.40645
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2896 - accuracy: 0.8813 - val_loss: 0.5807 - val_accuracy: 0.7875
# Epoch 117/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2458 - accuracy: 0.9143
# Epoch 117: val_loss improved from 0.40645 to 0.34083, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2827 - accuracy: 0.8875 - val_loss: 0.3408 - val_accuracy: 0.8000
# Epoch 118/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.2265 - accuracy: 0.9304
# Epoch 118: val_loss did not improve from 0.34083
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2243 - accuracy: 0.9250 - val_loss: 0.4838 - val_accuracy: 0.8375
# Epoch 119/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.2551 - accuracy: 0.8913
# Epoch 119: val_loss did not improve from 0.34083
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2408 - accuracy: 0.8906 - val_loss: 0.3478 - val_accuracy: 0.8625
# Epoch 120/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.2568 - accuracy: 0.9217
# Epoch 120: val_loss did not improve from 0.34083
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2934 - accuracy: 0.9094 - val_loss: 0.5103 - val_accuracy: 0.8125
# Epoch 121/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.2670 - accuracy: 0.9000
# Epoch 121: val_loss did not improve from 0.34083
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3131 - accuracy: 0.8938 - val_loss: 0.4034 - val_accuracy: 0.8250
# Epoch 122/200
# 18/32 [===============>..............] - ETA: 0s - loss: 0.2577 - accuracy: 0.9056
# Epoch 122: val_loss did not improve from 0.34083
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2420 - accuracy: 0.9219 - val_loss: 0.4326 - val_accuracy: 0.8250
# Epoch 123/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2208 - accuracy: 0.9381
# Epoch 123: val_loss did not improve from 0.34083
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2508 - accuracy: 0.9156 - val_loss: 0.4164 - val_accuracy: 0.8500
# Epoch 124/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.2177 - accuracy: 0.9043
# Epoch 124: val_loss improved from 0.34083 to 0.32928, saving model to /content/drive/MyDrive/ColabNotebooks/audio_classification.hdf5
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2185 - accuracy: 0.9094 - val_loss: 0.3293 - val_accuracy: 0.8750
# Epoch 125/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.2001 - accuracy: 0.9167
# Epoch 125: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1939 - accuracy: 0.9219 - val_loss: 0.3600 - val_accuracy: 0.8750
# Epoch 126/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.2306 - accuracy: 0.8909
# Epoch 126: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2251 - accuracy: 0.9000 - val_loss: 0.4245 - val_accuracy: 0.8625
# Epoch 127/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.4029 - accuracy: 0.9118
# Epoch 127: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3709 - accuracy: 0.8875 - val_loss: 0.4269 - val_accuracy: 0.8000
# Epoch 128/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.1791 - accuracy: 0.9516
# Epoch 128: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.9469 - val_loss: 0.4851 - val_accuracy: 0.8375
# Epoch 129/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1882 - accuracy: 0.9211
# Epoch 129: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1867 - accuracy: 0.9250 - val_loss: 0.3882 - val_accuracy: 0.8625
# Epoch 130/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.2564 - accuracy: 0.9000
# Epoch 130: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2363 - accuracy: 0.9094 - val_loss: 0.3609 - val_accuracy: 0.8625
# Epoch 131/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.2012 - accuracy: 0.9208
# Epoch 131: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2033 - accuracy: 0.9219 - val_loss: 0.4028 - val_accuracy: 0.8000
# Epoch 132/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.2178 - accuracy: 0.9043
# Epoch 132: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2368 - accuracy: 0.9062 - val_loss: 0.4885 - val_accuracy: 0.8500
# Epoch 133/200
# 24/32 [=====================>........] - ETA: 0s - loss: 0.2121 - accuracy: 0.9042
# Epoch 133: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2026 - accuracy: 0.9062 - val_loss: 0.3637 - val_accuracy: 0.8750
# Epoch 134/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.1878 - accuracy: 0.9391
# Epoch 134: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2434 - accuracy: 0.9156 - val_loss: 0.3991 - val_accuracy: 0.8750
# Epoch 135/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2324 - accuracy: 0.9190
# Epoch 135: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2328 - accuracy: 0.9125 - val_loss: 0.4193 - val_accuracy: 0.8750
# Epoch 136/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1394 - accuracy: 0.9550
# Epoch 136: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1443 - accuracy: 0.9469 - val_loss: 0.3855 - val_accuracy: 0.8375
# Epoch 137/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.2001 - accuracy: 0.9294
# Epoch 137: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1853 - accuracy: 0.9375 - val_loss: 0.4932 - val_accuracy: 0.8375
# Epoch 138/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.2974 - accuracy: 0.8913
# Epoch 138: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2633 - accuracy: 0.8969 - val_loss: 0.3755 - val_accuracy: 0.8625
# Epoch 139/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2727 - accuracy: 0.9143
# Epoch 139: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2331 - accuracy: 0.9312 - val_loss: 0.4007 - val_accuracy: 0.8250
# Epoch 140/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1801 - accuracy: 0.9300
# Epoch 140: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2185 - accuracy: 0.9219 - val_loss: 0.5741 - val_accuracy: 0.8250
# Epoch 141/200
# 14/32 [============>.................] - ETA: 0s - loss: 0.2470 - accuracy: 0.9357
# Epoch 141: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2457 - accuracy: 0.9250 - val_loss: 0.3310 - val_accuracy: 0.8625
# Epoch 142/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1833 - accuracy: 0.9350
# Epoch 142: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1775 - accuracy: 0.9438 - val_loss: 0.3785 - val_accuracy: 0.8625
# Epoch 143/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.2048 - accuracy: 0.9150
# Epoch 143: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.9312 - val_loss: 0.4097 - val_accuracy: 0.8500
# Epoch 144/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1964 - accuracy: 0.9227
# Epoch 144: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2137 - accuracy: 0.9125 - val_loss: 0.4207 - val_accuracy: 0.8250
# Epoch 145/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.2229 - accuracy: 0.9136
# Epoch 145: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2120 - accuracy: 0.9219 - val_loss: 0.4476 - val_accuracy: 0.8250
# Epoch 146/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1925 - accuracy: 0.9273
# Epoch 146: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2027 - accuracy: 0.9219 - val_loss: 0.4387 - val_accuracy: 0.8625
# Epoch 147/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.2248 - accuracy: 0.9211
# Epoch 147: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2519 - accuracy: 0.9187 - val_loss: 0.3997 - val_accuracy: 0.8500
# Epoch 148/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.2072 - accuracy: 0.9136
# Epoch 148: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1874 - accuracy: 0.9281 - val_loss: 0.4206 - val_accuracy: 0.8375
# Epoch 149/200
# 18/32 [===============>..............] - ETA: 0s - loss: 0.1616 - accuracy: 0.9389
# Epoch 149: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1721 - accuracy: 0.9406 - val_loss: 0.3798 - val_accuracy: 0.8500
# Epoch 150/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1403 - accuracy: 0.9455
# Epoch 150: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1470 - accuracy: 0.9375 - val_loss: 0.3569 - val_accuracy: 0.8750
# Epoch 151/200
# 16/32 [==============>...............] - ETA: 0s - loss: 0.0989 - accuracy: 0.9563
# Epoch 151: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1256 - accuracy: 0.9563 - val_loss: 0.4670 - val_accuracy: 0.8125
# Epoch 152/200
# 15/32 [=============>................] - ETA: 0s - loss: 0.1001 - accuracy: 0.9667
# Epoch 152: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1119 - accuracy: 0.9563 - val_loss: 0.6595 - val_accuracy: 0.8375
# Epoch 153/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.1983 - accuracy: 0.9304
# Epoch 153: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1694 - accuracy: 0.9406 - val_loss: 0.5615 - val_accuracy: 0.8250
# Epoch 154/200
# 23/32 [====================>.........] - ETA: 0s - loss: 0.1293 - accuracy: 0.9565
# Epoch 154: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1597 - accuracy: 0.9438 - val_loss: 0.5512 - val_accuracy: 0.8500
# Epoch 155/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1444 - accuracy: 0.9450
# Epoch 155: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1586 - accuracy: 0.9344 - val_loss: 0.4372 - val_accuracy: 0.8500
# Epoch 156/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1570 - accuracy: 0.9143
# Epoch 156: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1676 - accuracy: 0.9156 - val_loss: 0.5195 - val_accuracy: 0.8000
# Epoch 157/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1168 - accuracy: 0.9409
# Epoch 157: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1030 - accuracy: 0.9531 - val_loss: 0.4492 - val_accuracy: 0.8625
# Epoch 158/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.1083 - accuracy: 0.9471
# Epoch 158: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9469 - val_loss: 0.5023 - val_accuracy: 0.8125
# Epoch 159/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1920 - accuracy: 0.9273
# Epoch 159: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1928 - accuracy: 0.9281 - val_loss: 0.6007 - val_accuracy: 0.8875
# Epoch 160/200
# 14/32 [============>.................] - ETA: 0s - loss: 0.2102 - accuracy: 0.9429
# Epoch 160: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2019 - accuracy: 0.9375 - val_loss: 0.4031 - val_accuracy: 0.9000
# Epoch 161/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.2105 - accuracy: 0.9235
# Epoch 161: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2196 - accuracy: 0.9281 - val_loss: 0.6635 - val_accuracy: 0.8250
# Epoch 162/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.2387 - accuracy: 0.9182
# Epoch 162: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2225 - accuracy: 0.9156 - val_loss: 0.5393 - val_accuracy: 0.8250
# Epoch 163/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.2205 - accuracy: 0.9045
# Epoch 163: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2077 - accuracy: 0.9187 - val_loss: 0.6247 - val_accuracy: 0.8250
# Epoch 164/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1722 - accuracy: 0.9364
# Epoch 164: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1617 - accuracy: 0.9438 - val_loss: 0.5792 - val_accuracy: 0.8375
# Epoch 165/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1129 - accuracy: 0.9524
# Epoch 165: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1642 - accuracy: 0.9406 - val_loss: 0.4855 - val_accuracy: 0.8250
# Epoch 166/200
# 18/32 [===============>..............] - ETA: 0s - loss: 0.1724 - accuracy: 0.9444
# Epoch 166: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1635 - accuracy: 0.9438 - val_loss: 0.4407 - val_accuracy: 0.8375
# Epoch 167/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1572 - accuracy: 0.9526
# Epoch 167: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1205 - accuracy: 0.9719 - val_loss: 0.4589 - val_accuracy: 0.8250
# Epoch 168/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1599 - accuracy: 0.9545
# Epoch 168: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1482 - accuracy: 0.9563 - val_loss: 0.6143 - val_accuracy: 0.7750
# Epoch 169/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1686 - accuracy: 0.9250
# Epoch 169: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1685 - accuracy: 0.9312 - val_loss: 0.4914 - val_accuracy: 0.8250
# Epoch 170/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1832 - accuracy: 0.9571
# Epoch 170: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2013 - accuracy: 0.9469 - val_loss: 0.4222 - val_accuracy: 0.8500
# Epoch 171/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1504 - accuracy: 0.9400
# Epoch 171: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1418 - accuracy: 0.9469 - val_loss: 0.3865 - val_accuracy: 0.8875
# Epoch 172/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1158 - accuracy: 0.9524
# Epoch 172: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1364 - accuracy: 0.9500 - val_loss: 0.5336 - val_accuracy: 0.8625
# Epoch 173/200
# 16/32 [==============>...............] - ETA: 0s - loss: 0.1548 - accuracy: 0.9563
# Epoch 173: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2253 - accuracy: 0.9375 - val_loss: 0.5187 - val_accuracy: 0.8500
# Epoch 174/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1865 - accuracy: 0.9526
# Epoch 174: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1579 - accuracy: 0.9438 - val_loss: 0.4992 - val_accuracy: 0.8500
# Epoch 175/200
# 13/32 [===========>..................] - ETA: 0s - loss: 0.0880 - accuracy: 0.9769
# Epoch 175: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1236 - accuracy: 0.9625 - val_loss: 0.5025 - val_accuracy: 0.8375
# Epoch 176/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1485 - accuracy: 0.9316
# Epoch 176: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1309 - accuracy: 0.9438 - val_loss: 0.4863 - val_accuracy: 0.8250
# Epoch 177/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1426 - accuracy: 0.9333
# Epoch 177: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1463 - accuracy: 0.9375 - val_loss: 0.6461 - val_accuracy: 0.8250
# Epoch 178/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1471 - accuracy: 0.9381
# Epoch 178: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1330 - accuracy: 0.9469 - val_loss: 0.5033 - val_accuracy: 0.8625
# Epoch 179/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.1771 - accuracy: 0.9294
# Epoch 179: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1797 - accuracy: 0.9344 - val_loss: 0.5290 - val_accuracy: 0.8750
# Epoch 180/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.1441 - accuracy: 0.9471
# Epoch 180: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1320 - accuracy: 0.9500 - val_loss: 0.4874 - val_accuracy: 0.9125
# Epoch 181/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1898 - accuracy: 0.9316
# Epoch 181: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.9344 - val_loss: 0.5227 - val_accuracy: 0.8375
# Epoch 182/200
# 18/32 [===============>..............] - ETA: 0s - loss: 0.1917 - accuracy: 0.9500
# Epoch 182: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1593 - accuracy: 0.9500 - val_loss: 0.4370 - val_accuracy: 0.8500
# Epoch 183/200
# 15/32 [=============>................] - ETA: 0s - loss: 0.1215 - accuracy: 0.9533
# Epoch 183: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1175 - accuracy: 0.9594 - val_loss: 0.5173 - val_accuracy: 0.8500
# Epoch 184/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1685 - accuracy: 0.9474
# Epoch 184: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1822 - accuracy: 0.9406 - val_loss: 0.4279 - val_accuracy: 0.8625
# Epoch 185/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1440 - accuracy: 0.9591
# Epoch 185: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1505 - accuracy: 0.9500 - val_loss: 0.5410 - val_accuracy: 0.8125
# Epoch 186/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1371 - accuracy: 0.9524
# Epoch 186: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1496 - accuracy: 0.9438 - val_loss: 0.4560 - val_accuracy: 0.8875
# Epoch 187/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1480 - accuracy: 0.9364
# Epoch 187: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1237 - accuracy: 0.9469 - val_loss: 0.3352 - val_accuracy: 0.9125
# Epoch 188/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.0624 - accuracy: 0.9941
# Epoch 188: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0807 - accuracy: 0.9750 - val_loss: 0.3715 - val_accuracy: 0.8750
# Epoch 189/200
# 22/32 [===================>..........] - ETA: 0s - loss: 0.1158 - accuracy: 0.9636
# Epoch 189: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1165 - accuracy: 0.9625 - val_loss: 0.7520 - val_accuracy: 0.8000
# Epoch 190/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.1575 - accuracy: 0.9429
# Epoch 190: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9406 - val_loss: 0.4674 - val_accuracy: 0.8500
# Epoch 191/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1732 - accuracy: 0.9105
# Epoch 191: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1441 - accuracy: 0.9312 - val_loss: 0.4746 - val_accuracy: 0.8750
# Epoch 192/200
# 18/32 [===============>..............] - ETA: 0s - loss: 0.1323 - accuracy: 0.9500
# Epoch 192: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1505 - accuracy: 0.9469 - val_loss: 0.6498 - val_accuracy: 0.8750
# Epoch 193/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1413 - accuracy: 0.9526
# Epoch 193: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1741 - accuracy: 0.9438 - val_loss: 0.5184 - val_accuracy: 0.8375
# Epoch 194/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1104 - accuracy: 0.9600
# Epoch 194: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1404 - accuracy: 0.9594 - val_loss: 0.4114 - val_accuracy: 0.8250
# Epoch 195/200
# 17/32 [==============>...............] - ETA: 0s - loss: 0.0847 - accuracy: 0.9706
# Epoch 195: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0832 - accuracy: 0.9719 - val_loss: 0.5459 - val_accuracy: 0.7750
# Epoch 196/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1153 - accuracy: 0.9650
# Epoch 196: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1704 - accuracy: 0.9438 - val_loss: 0.4944 - val_accuracy: 0.8375
# Epoch 197/200
# 21/32 [==================>...........] - ETA: 0s - loss: 0.2251 - accuracy: 0.9476
# Epoch 197: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2097 - accuracy: 0.9344 - val_loss: 0.4800 - val_accuracy: 0.8500
# Epoch 198/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1389 - accuracy: 0.9368
# Epoch 198: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1465 - accuracy: 0.9469 - val_loss: 0.4868 - val_accuracy: 0.8250
# Epoch 199/200
# 20/32 [=================>............] - ETA: 0s - loss: 0.1756 - accuracy: 0.9600
# Epoch 199: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1670 - accuracy: 0.9469 - val_loss: 0.4320 - val_accuracy: 0.8625
# Epoch 200/200
# 19/32 [================>.............] - ETA: 0s - loss: 0.1447 - accuracy: 0.9316
# Epoch 200: val_loss did not improve from 0.32928
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1127 - accuracy: 0.9500 - val_loss: 0.5443 - val_accuracy: 0.8500
# Training completed in time:  0:00:41.759081

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8500000238418579

# %%
def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import itertools
cm_plot_labels = ['False' , 'True']
y_pred=model.predict(X_test) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)

plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[13  0  1  0]
#  [ 0 26  2  0]
#  [ 0  0 18  1]
#  [ 6  0  2 11]]

# %%
#model.predict_classes(X_test)
predict_x=model.predict(X_test) 
classes_x=np.argmax(predict_x,axis=1)
print(classes_x)
# Out:
# [2 1 3 3 0 1 0 0 2 0 1 2 2 0 1 1 1 2 3 3 0 0 2 2 2 2 2 1 1 2 3 1 2 0 1 2 2
#  3 3 0 2 2 1 1 1 1 2 0 3 0 0 2 1 3 0 3 1 1 1 1 1 0 1 3 3 0 2 2 0 1 2 0 1 1
#  2 1 0 1 0 2]

# %%
filename="/content/drive/MyDrive/tes1/curved_mayo_sicssor.wav"
#preprocess the audio file
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
#Reshape MFCC feature to 2-D array
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
#predicted_label=model.predict_classes(mfccs_scaled_features)
x_predict=model.predict(mfccs_scaled_features) 
predicted_label=np.argmax(x_predict,axis=1)
print(predicted_label)
prediction_class = labelencoder.inverse_transform(predicted_label) 
print(prediction_class)
# Out:
# [3]
# ['straight_mayo_sicssor']

# %%
import os
from sklearn.metrics import accuracy_score
from numpy import sort

# folder path
dir_path = r'/content/drive/MyDrive/nntest/'

# list to store files
res = []
y_true = []
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        filename= dir_path + path
        #preprocess the audio file
        audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
        mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
        #Reshape MFCC feature to 2-D array
        mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
        #predicted_label=model.predict_classes(mfccs_scaled_features)
        x_predict=model.predict(mfccs_scaled_features) 
        predicted_label=np.argmax(x_predict,axis=1)
        prediction_class = labelencoder.inverse_transform(predicted_label)
        res.append(predicted_label[0])
        new_filename = path.split('_')
        pred_file = new_filename[1].split('.')
        final_label = pred_file[0]
        y_true.append(int(final_label))


print(y_true)
print(res)
score = accuracy_score(y_true = y_true, y_pred = res)
print(score)
# Out:
# [1, 1, 3, 3, 3, 3, 0, 0, 0, 0, 2, 2, 2, 2, 1, 1, 1, 1, 3, 3, 3, 3, 2, 2, 2, 2, 2, 0, 0, 0, 0, 3]
# [2, 2, 2, 1, 1, 1, 1, 3, 1, 3, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 2, 2, 1, 1]
# 0.28125

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig('NLP Visualization.jpg')

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics


confusion_matrix = metrics.confusion_matrix(y_true, res)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
from keras.engine import sequential
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import plot_confusion_matrix
model = sequential()
model.fit(X_train , y_train)
disp = plot_confusion_matrix( model , X_test,y_test , cmap = 'Blues')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-82bc54cbb053> in <module>
#       3 from sklearn.linear_model import LogisticRegression
#       4 from sklearn.metrics import plot_confusion_matrix
# ----> 5 model = sequential()
#       6 model.fit(X_train , y_train)
#       7 disp = plot_confusion_matrix( model , X_test,y_test , cmap = 'Blues')
#
# TypeError: 'module' object is not callable
